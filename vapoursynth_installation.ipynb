# %% [markdown]
# ### Vapoursynth

# %% [markdown]
# #### Zimg(needed in vapoursynth build)

# %%
# !wget "https://github.com/sekrit-twc/zimg/archive/refs/tags/release-3.0.4.tar.gz" -qq
# !tar -xvf release-3.0.4.tar.gz > tar.log
# %cd zimg-release-3.0.4/
# Out:
# /content/zimg-release-3.0.4

# %%
# !apt install libtool > apt_install.log
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
# !./autogen.sh > autogen.log
# !./configure > configure.log
# !make > make1.log
# !make install > make_install.log
# Out:
# autoreconf: Entering directory `.'
# autoreconf: configure.ac: not using Gettext
# autoreconf: running: aclocal --force -I m4
# autoreconf: configure.ac: tracing
# autoreconf: running: libtoolize --copy --force
# autoreconf: running: /usr/bin/autoconf --force
# autoreconf: configure.ac: not using Autoheader
# autoreconf: running: automake --add-missing --copy --force-missing
# configure.ac:10: installing './compile'
# configure.ac:10: installing './config.guess'
# configure.ac:10: installing './config.sub'
# configure.ac:7: installing './install-sh'
# configure.ac:7: installing './missing'
# Makefile.am: installing './depcomp'
# parallel-tests: installing './test-driver'
# autoreconf: Leaving directory `.'

# %% [markdown]
# #### The Vapoursynth Installation

# %%
# %cd /content
# Out:
# /content

# %%
# !wget "https://github.com/vapoursynth/vapoursynth/archive/refs/tags/R61.tar.gz" -qq
# !tar -xvf R61.tar.gz > a.log
# %cd vapoursynth-R61/
# Out:
# /content/vapoursynth-R61

# %%
# !./autogen.sh > autogen.log
# !./configure > configure.log
# !make > make1.log
# !make install > make_install.log
# Out:
# autoreconf: Entering directory `.'
# autoreconf: configure.ac: not using Gettext
# autoreconf: running: aclocal --force -I m4
# autoreconf: configure.ac: tracing
# autoreconf: running: libtoolize --copy --force
# autoreconf: running: /usr/bin/autoconf --force
# autoreconf: configure.ac: not using Autoheader
# autoreconf: running: automake --add-missing --copy --force-missing
# configure.ac:9: installing './compile'
# configure.ac:9: installing './config.guess'
# configure.ac:9: installing './config.sub'
# configure.ac:6: installing './install-sh'
# configure.ac:6: installing './missing'
# Makefile.am: installing './depcomp'
# autoreconf: Leaving directory `.'
# In file included from src/core/expr/jitcompiler_x86.cpp:28:
# src/core/expr/jitasm.h: In constructor ‘jitasm::detail::ResultT<float, 4>::ResultT(float)’:
# src/core/expr/jitasm.h:8634:42: warning: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
# ...

# %%
# This is for avoiding libvapoursynth.so import error. Adding libraries to path.
# The notebook will restart the runtime. So, don't worry.
import os, sys
os.environ["LD_LIBRARY_PATH"] = f"/usr/local/lib:{os.environ.get('LD_LIBRARY_PATH', '')}"
os.execve(sys.executable, [sys.executable] + sys.argv, os.environ)

# %%
# !python -m pip install vapoursynth
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.1/559.1 KB 9.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for vapoursynth: filename=VapourSynth-61-cp38-cp38-linux_x86_64.whl size=2849508 sha256=b57500175aaf7c9a971e1f1fe281b5903a0a75fc3246c0e38faf13d07af3ff78
#   Stored in directory: /root/.cache/pip/wheels/92/34/25/e9f1952a32eaf409d104c359140c5022a7c4065483d9e2320c
# Successfully built vapoursynth
# ...

# %% [markdown]
# #### Test vapoursynth

# %%
import vapoursynth
print(vapoursynth.__file__)
print(vapoursynth.core)
# Out:
# /usr/local/lib/python3.8/dist-packages/vapoursynth.cpython-38-x86_64-linux-gnu.so
# ...
